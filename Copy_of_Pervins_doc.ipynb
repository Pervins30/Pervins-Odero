# %% [markdown]
# <a href="https://colab.research.google.com/github/Pervins30/Pervins-Odero/blob/main/Copy_of_Pervins_doc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib import rcParams
df=pd.read_csv("/content/HousingPrices-Amsterdam-August-2021.csv")
print(df)
# Out:
#      Unnamed: 0                                 Address      Zip     Price  \
# 0             1            Blasiusstraat 8 2, Amsterdam  1091 CR  685000.0
# 1             2  Kromme Leimuidenstraat 13 H, Amsterdam  1059 EL  475000.0
# 2             3              Zaaiersweg 11 A, Amsterdam  1097 SM  850000.0
# 3             4            Tenerifestraat 40, Amsterdam  1060 TH  580000.0
# 4             5              Winterjanpad 21, Amsterdam  1036 KN  720000.0
# ..          ...                                     ...      ...       ...
# 919         920                     Ringdijk, Amsterdam  1097 AE  750000.0
# 920         921         Kleine Beerstraat 31, Amsterdam  1033 CP  350000.0
# 921         922       Stuyvesantstraat 33 II, Amsterdam  1058 AK  350000.0
# 922         923   John Blankensteinstraat 51, Amsterdam  1095 MB  599000.0
# 923         924      S. F. van Ossstraat 334, Amsterdam  1068 JS  300000.0
#
#      Area  Room       Lon        Lat
# ...

# %%
plt.rcParams['figure.figsize'] = (10,8)
sns.set_theme(style="darkgrid")

# %%
df = df [['Price','Area','Room','Lon','Lat']]
df['Price'] = df['Price'].astype(float)

# %%
df.isnull().values.any()
# Out:
# True

# %%
df = df.dropna()

# %%
sns.relplot(x="Area", y="Price", hue="Room", data=df)
plt.show()

# %%
sns.heatmap(df.corr(), annot=True, fmt=".2f")
plt.show()
